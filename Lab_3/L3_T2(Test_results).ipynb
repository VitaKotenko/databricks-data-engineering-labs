# %% [markdown]
# ### Initial streaming load
#
# The producer sent 362 vehicle events to Azure Event Hubs.
#
# ![зображення_1789116501330.png](./screenshots/зображення_1789116501330.png "зображення_1789116501330.png")
#
#
#
# ![зображення_1789116551332.png](./screenshots/зображення_1789116551332.png "зображення_1789116551332.png")
#
# All 362 events were successfully loaded into the Bronze table.

# %% [markdown]
# ### Incremental load
#
# A second batch of 360 events was sent to Event Hubs.
#
# ![зображення_1789116634502.png](./screenshots/зображення_1789116634502.png "зображення_1789116634502.png")
#
# ![зображення_1789116646915.png](./screenshots/зображення_1789116646915.png "зображення_1789116646915.png")
#
# The Bronze table increased from 362 to 722 rows, confirming incremental processing with the existing checkpoint.

# %% [markdown]
# ### Databricks Job execution
#
# The streaming consumer was successfully executed as a Databricks Job.
#
# ![зображення_1789118044606.png](./screenshots/зображення_1789118044606.png "зображення_1789118044606.png")
#
# ![зображення_1789116874625.png](./screenshots/зображення_1789116874625.png "зображення_1789116874625.png")
#
# After processing another batch of 365 events, the Bronze table contained 1087 rows.
