# %% [markdown]
# # Azure Resources Screenshots

# %% [markdown]
# ![зображення_1788805286602.png](./зображення_1788805286602.png "зображення_1788805286602.png")

# %% [markdown]
# ![зображення_1788805304379.png](./зображення_1788805304379.png "зображення_1788805304379.png")

# %% [markdown]
# ![зображення_1788805319829.png](./зображення_1788805319829.png "зображення_1788805319829.png")

# %% [markdown]
# ![зображення_1788805330291.png](./зображення_1788805330291.png "зображення_1788805330291.png")
